# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %%
## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*
#
# Are students choosing a particular test to get better results to enter their college of choice?

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def get_mean(val):
    return(sum(val)/len(val))


get_mean([3,4,5,6,2,7,4,8,9])
# Out:
# 5.333333333333333

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

# def st_dev(lst):
#     total = 0
#     for i in lst:
#         total += (i-get_mean(lst))**2
#     return (total/len(lst)) ** (1/2)


def st_dev(lst):
    total = sum([(i - get_mean(lst)) ** 2 for i in lst])
    return (total/len(lst)) ** (1/2)

    
print(st_dev([3,4,5,6,2,7,4,8,9]))
# Out:
# 2.211083193570267

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:

def format_percent(value):
    """ data_clean takes in a string value and removes % sign. Thereafter, casts resultant string into a float value"""
    num = float(value.replace('%',''))
    return num/100
    
    
format_percent('30.56%')
# Out:
# 0.3056

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce
import re

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code

sat_2017 = pd.read_csv('../data/sat_2017.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')

print(sat_2017.head(5))
print(sat_2018.head(5))
print(act_2017.head(5))
print(act_2018.head(5))



def convert_float(tmp):
    try:
        if re.compile(r"[a-zA-Z]").search(tmp):
            return float(re.sub(r"[a-zA-Z]",'',tmp))
        else:
            return float(tmp)
    except ValueError:
        return None
    
    
def get_diff(tmp):
    tmp['composite_diff'] = round(tmp['act_2017_composite'] - tmp['act_2018_composite'],1)
    tmp['total_diff'] = round(tmp['sat_2017_total'] - tmp['sat_2018_total'],1)
    tmp['act_participation_diff'] = abs(round(tmp['act_2017_participation'] - tmp['act_2018_participation'],2))
    tmp['sat_participation_diff'] = abs(round(tmp['sat_2017_participation'] - tmp['sat_2018_participation'],2))
    return tmp

def fix_sat_math(row):
    if row['Math'] < 200:
        row['Math'] = row['Total'] - row['Evidence-Based Reading and Writing']
        
    return row
        


act_2018.drop_duplicates(inplace=True)      # Remove duplicate Maine
act_2018.reset_index(inplace=True)          # Reset index after removal
act_2018.drop('index',axis=1,inplace=True)  # Drop index column
act_2018['State'] = (act_2018['State'].str.title()).str.replace('Of','of')     # Correctly re-title states
act_2017['Composite'] = act_2017['Composite'].apply(convert_float,1)
act_2017['Participation'] = act_2017['Participation'].apply(format_percent,1)
act_2018['Participation'] = act_2018['Participation'].apply(format_percent,1)
sat_2017['Participation'] = sat_2017['Participation'].apply(format_percent,1)
sat_2018['Participation'] = sat_2018['Participation'].apply(format_percent,1)
act_2017.drop(act_2017[act_2017['State'] == 'National'].index,inplace=True)    # Removes 'National' row record
sat_2017 = sat_2017.apply(fix_sat_math,1)     # Fixes 2017 SAT Maryland Math score, minimal SAT is 200 per category

# Drop columns as data is incorrect based on calculation
act_2017.drop('Composite',axis=1,inplace=True) 
sat_2017.drop('Total',axis=1,inplace=True) 
sat_2018.drop('Total',axis=1,inplace=True)

# Recalculate Composites and Totals
act_2017['Composite'] = round((act_2017['English'] + act_2017['Math'] + act_2017['Reading'] + act_2017['Science']) / 4,1)
sat_2017['Total'] = sat_2017['Evidence-Based Reading and Writing'] + sat_2017['Math']
sat_2018['Total'] = sat_2018['Evidence-Based Reading and Writing'] + sat_2018['Math']


act_2017.rename(columns={
    'State':'state',
    'English':'act_2017_english',
    'Math':'act_2017_math',
    'Reading':'act_2017_reading',
    'Science':'act_2017_science',
    'Participation':'act_2017_participation',
    'Composite':'act_2017_composite'
}, inplace=True)

act_2018.rename(columns={
    'State':'state',
    'Participation':'act_2018_participation',
    'Composite':'act_2018_composite'
}, inplace=True)

sat_2017.rename(columns={
    'State':'state',
    'Participation':'sat_2017_participation',
    'Evidence-Based Reading and Writing':'sat_2017_ebrw',
    'Math':'sat_2017_math',
    'Total':'sat_2017_total'
}, inplace=True)

sat_2018.rename(columns={
    'State':'state',
    'Participation':'sat_2018_participation',
    'Evidence-Based Reading and Writing':'sat_2018_ebrw',
    'Math':'sat_2018_math',
    'Total':'sat_2018_total'
}, inplace=True)


datasets = [act_2017,act_2018,sat_2017,sat_2018]

df = reduce(lambda left, right: pd.merge(left,right,on='state'), datasets)   # iteratively merge datasets from left to right

data = df.apply(get_diff, axis=1)

data.to_csv('../data/act_sat_2017_2018.csv')
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   act_2017_participation  51 non-null     float64
#  2   act_2017_english        51 non-null     float64
#  3   act_2017_math           51 non-null     float64
#  4   act_2017_reading        51 non-null     float64
#  5   act_2017_science        51 non-null     float64
#  6   act_2017_composite      51 non-null     float64
#  7   act_2018_participation  51 non-null     float64
#  8   act_2018_composite      51 non-null     float64
#  9   sat_2017_participation  51 non-null     float64
#  10  sat_2017_ebrw           51 non-null     int64
#  11  sat_2017_math           51 non-null     int64
#  12  sat_2017_total          51 non-null     int64
#  13  sat_2018_participation  51 non-null     float64
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|act_2017.csv|State of ACT Participation and Results|
# |**act_2017_participation**|*float*|act_2017.csv|Participation % of ACT in the related State in 2017|
# |**act_2017_english**|*float*|act_2017.csv|Average results for English in the related State|
# |**act_2017_math**|*float*|act_2017.csv|Average results for Math in the related State|
# |**act_2017_reading**|*float*|act_2017.csv|Average results for Reading in the related State|
# |**act_2017_science**|*float*|act_2017.csv|Average results for Science in the related State|
# |**act_2017_composite**|*float*|act_2017.csv|Average of English, Math, Reading and Science scores in 2017, rounded to the nearest whole number|
# |**act_2018_participation**|*float*|act_2018.csv|Participation % of ACT in the related State in 2018|
# |**act_2018_composite**|*float*|act_2018.csv|Average of English, Math, Reading and Science scores in 2018, rounded to the nearest whole number|
# **sat_2017_participation**|*float*|sat_2017.csv|Participation % of SAT in the related State in 2017|
# **sat_2017_ebrw**|*int64*|sat_2017.csv|Average Evidence-Based Reading and Writing SAT score for the related State in 2017|
# **sat_2017_math**|*int64*|sat_2017.csv|Average Math SAT score for the related State in 2017|
# **sat_2017_total**|*int64*|sat_2017.csv|Average Total SAT score for the related State in 2017|
# **sat_2018_participation**|*float64*|sat_2018.csv|Participation % of SAT in the related State in 2018|
# **sat_2018_ebrw**|*int64*|sat_2018.csv|Average Evidence-Based Reading and Writing SAT score for the related State in 2018|
# **sat_2018_math**|*int64*|sat_2018.csv|Average Math SAT score for the related State in 2018|
# **sat_2018_total**|*int64*|sat_2018.csv|Average Total SAT score for the related State in 2018|
# **composite_diff**|*float64*||Difference in Average Composite ACT scores between 2017 and 2018|
# **total_diff**|*int64*||Difference in Average Total SAT scores between 2017 and 2018|
# **act_participation_diff**|*float64*||Difference in participation % for ACT between 2017 and 2018|
# **sat_participation_diff**|*float64*||Difference in participation % for SAT between 2017 and 2018|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
data.head(8)
# Out:
#          state  act_2017_participation  act_2017_english  act_2017_math  \
# 0      Alabama                    1.00              18.9           18.4
# 1       Alaska                    0.65              18.7           19.8
# 2      Arizona                    0.62              18.6           19.8
# 3     Arkansas                    1.00              18.9           19.0
# 4   California                    0.31              22.5           22.7
# 5     Colorado                    1.00              20.1           20.3
# 6  Connecticut                    0.31              25.5           24.6
# 7     Delaware                    0.18              24.1           23.4
#
#    act_2017_reading  act_2017_science  act_2017_composite  \
# 0              19.7              19.4                19.1
# 1              20.4              19.9                19.7
# 2              20.1              19.8                19.6
# 3              19.7              19.5                19.3
# ...

# %%
sd = {k: st_dev(data[k]) for k in data.select_dtypes(include=np.number)}
sd  # Slight difference on st_dev, vs describe()
# Out:
# {'act_2017_participation': 0.3182417575123181,
#  'act_2017_english': 2.3304876369363363,
#  'act_2017_math': 1.9624620273436781,
#  'act_2017_reading': 2.0469029314842646,
#  'act_2017_science': 3.151107895464408,
#  'act_2017_composite': 2.029859759210165,
#  'act_2018_participation': 0.33701735820410317,
#  'act_2018_composite': 2.090779082141178,
#  'sat_2017_participation': 0.3492907076664507,
#  'sat_2017_ebrw': 45.21697020437866,
#  'sat_2017_math': 46.65713364485503,
#  'sat_2017_total': 91.57639048421622,
#  'sat_2018_participation': 0.3694661922353942,
#  'sat_2018_ebrw': 47.03460978357609,
#  'sat_2018_math': 47.30194550378352,
#  'sat_2018_total': 93.26114360945468,
#  'composite_diff': 0.9033620828173216,
#  'total_diff': 50.24287799973516,
#  'act_participation_diff': 0.12609139078945383,
#  'sat_participation_diff': 0.17515654556879684}

# %% [markdown]
# ---
# ### Top 5 states with highest ACT participation in 2017 and 2018

# %%
#Code:
data.sort_values(['act_2017_participation'],ascending=False)[['state','act_2017_participation', 'act_2018_participation','act_participation_diff']].head()
#data.loc[(data['act_2017_participation'] >= 0.75) & (data['act_2018_participation'] >= 0.75), ['state','act_2017_participation','act_2018_participation']]
# Out:
#         state  act_2017_participation  act_2018_participation  \
# 0     Alabama                     1.0                     1.0
# 17   Kentucky                     1.0                     1.0
# 49  Wisconsin                     1.0                     1.0
# 44       Utah                     1.0                     1.0
# 42  Tennessee                     1.0                     1.0
#
#     act_participation_diff
# 0                      0.0
# 17                     0.0
# 49                     0.0
# 44                     0.0
# 42                     0.0

# %%
data.sort_values(['act_2018_participation'],ascending=False)[['state','act_2017_participation', 'act_2018_participation','act_participation_diff']].head()
# Out:
#         state  act_2017_participation  act_2018_participation  \
# 0     Alabama                     1.0                     1.0
# 17   Kentucky                     1.0                     1.0
# 49  Wisconsin                     1.0                     1.0
# 44       Utah                     1.0                     1.0
# 42  Tennessee                     1.0                     1.0
#
#     act_participation_diff
# 0                      0.0
# 17                     0.0
# 49                     0.0
# 44                     0.0
# 42                     0.0

# %% [markdown]
# The top 5 states for ACT participation still maintain the same from 2017 and 2018, with no reduction in participation rates. This is likely because these states require the ACT (as of 2017) as a statewide college admission test

# %% [markdown]
# ### Top 5 states with lowest ACT participation in  2017 and 2018

# %%
data.sort_values(['act_2017_participation'],ascending=True)[['state','act_2017_participation', 'act_2018_participation','act_participation_diff']].head()
#data.loc[(data['act_2017_participation'] <= 0.25) & (data['act_2018_participation'] <= 0.25), ['state','act_2017_participation','act_2018_participation']]
# Out:
#             state  act_2017_participation  act_2018_participation  \
# 19          Maine                    0.08                    0.07
# 29  New Hampshire                    0.18                    0.16
# 7        Delaware                    0.18                    0.17
# 39   Rhode Island                    0.21                    0.15
# 38   Pennsylvania                    0.23                    0.20
#
#     act_participation_diff
# 19                    0.01
# 29                    0.02
# 7                     0.01
# 39                    0.06
# 38                    0.03

# %%
data.sort_values(['act_2018_participation'],ascending=True)[['state','act_2017_participation', 'act_2018_participation','act_participation_diff']].head()
# Out:
#             state  act_2017_participation  act_2018_participation  \
# 19          Maine                    0.08                    0.07
# 39   Rhode Island                    0.21                    0.15
# 29  New Hampshire                    0.18                    0.16
# 7        Delaware                    0.18                    0.17
# 38   Pennsylvania                    0.23                    0.20
#
#     act_participation_diff
# 19                    0.01
# 39                    0.06
# 29                    0.02
# 7                     0.01
# 38                    0.03

# %% [markdown]
# Except for Pennsylvania, the other 4 states require the SAT in order for students to graduate. This would explain the low ACT participation rate for these states.

# %% [markdown]
# ### Top 5 states with highest SAT participation in 2017 and 2018

# %%
data.sort_values(['sat_2017_participation'],ascending=False)[['state','sat_2017_participation', 'sat_2018_participation','sat_participation_diff']].head()
#data.loc[(data['sat_2017_participation'] >= 0.75) & (data['sat_2018_participation'] >= 0.75), ['state','sat_2017_participation','sat_2018_participation']]
# Out:
#                    state  sat_2017_participation  sat_2018_participation  \
# 8   District of Columbia                    1.00                    0.92
# 22              Michigan                    1.00                    1.00
# 6            Connecticut                    1.00                    1.00
# 7               Delaware                    1.00                    1.00
# 29         New Hampshire                    0.96                    0.96
#
#     sat_participation_diff
# 8                     0.08
# 22                    0.00
# 6                     0.00
# 7                     0.00
# 29                    0.00

# %%
data.sort_values(['sat_2018_participation'],ascending=False)[['state','sat_2017_participation', 'sat_2018_participation','sat_participation_diff']].head(5)
# Out:
#           state  sat_2017_participation  sat_2018_participation  \
# 5      Colorado                    0.11                     1.0
# 6   Connecticut                    1.00                     1.0
# 7      Delaware                    1.00                     1.0
# 22     Michigan                    1.00                     1.0
# 12        Idaho                    0.93                     1.0
#
#     sat_participation_diff
# 5                     0.89
# 6                     0.00
# 7                     0.00
# 22                    0.00
# 12                    0.07

# %% [markdown]
# Most of the states with high SAT participation in 2017 and 2018 require the SAT in order to graduate from high school. It is a requirement to take the SAT in Colorado since 2016-2017, hence we don't see it appearing as one of the top states for SAT participation in 2017 possibly due to gradual changes, but it becomes one of the top 5 states with a high difference of participation % between 2017-2018.

# %% [markdown]
# ### Top 5 states with lowest SAT participation in 2017 and 2018

# %%
data.sort_values(['sat_2017_participation'],ascending=True)[['state','sat_2017_participation', 'sat_2018_participation','sat_participation_diff']].head()
# Out:
#            state  sat_2017_participation  sat_2018_participation  \
# 34  North Dakota                    0.02                    0.02
# 24   Mississippi                    0.02                    0.03
# 15          Iowa                    0.02                    0.03
# 25      Missouri                    0.03                    0.04
# 44          Utah                    0.03                    0.04
#
#     sat_participation_diff
# 34                    0.00
# 24                    0.01
# 15                    0.01
# 25                    0.01
# 44                    0.01

# %%
data.sort_values(['sat_2018_participation'],ascending=True)[['state','sat_2017_participation', 'sat_2018_participation','sat_participation_diff']].head()
# Out:
#            state  sat_2017_participation  sat_2018_participation  \
# 34  North Dakota                    0.02                    0.02
# 50       Wyoming                    0.03                    0.03
# 41  South Dakota                    0.03                    0.03
# 27      Nebraska                    0.03                    0.03
# 49     Wisconsin                    0.03                    0.03
#
#     sat_participation_diff
# 34                     0.0
# 50                     0.0
# 41                     0.0
# 27                     0.0
# 49                     0.0

# %% [markdown]
# And similarly, some of the states listed here have the ACT as a requirement to graduate, therefore having low SAT participation count.

# %% [markdown]
# ---
# ### Top 5 states with highest ACT average composite scores in 2017 and 2018

# %%
data.sort_values('act_2017_composite',ascending=False)[['state','act_2017_composite', 'act_2018_composite','act_2017_participation','act_2018_participation','composite_diff']].head()
# Out:
#             state  act_2017_composite  act_2018_composite  \
# 29  New Hampshire                25.4                25.1
# 21  Massachusetts                25.3                25.5
# 6     Connecticut                25.1                25.6
# 19          Maine                24.2                24.0
# 32       New York                24.1                24.5
#
#     act_2017_participation  act_2018_participation  composite_diff
# 29                    0.18                    0.16             0.3
# 21                    0.29                    0.25            -0.2
# 6                     0.31                    0.26            -0.5
# 19                    0.08                    0.07             0.2
# 32                    0.31                    0.27            -0.4

# %%
data.sort_values('act_2018_composite',ascending=False)[['state','act_2017_composite', 'act_2018_composite','act_2017_participation','act_2018_participation','composite_diff']].head()
# Out:
#             state  act_2017_composite  act_2018_composite  \
# 6     Connecticut                25.1                25.6
# 21  Massachusetts                25.3                25.5
# 29  New Hampshire                25.4                25.1
# 32       New York                24.1                24.5
# 22       Michigan                24.0                24.2
#
#     act_2017_participation  act_2018_participation  composite_diff
# 6                     0.31                    0.26            -0.5
# 21                    0.29                    0.25            -0.2
# 29                    0.18                    0.16             0.3
# 32                    0.31                    0.27            -0.4
# 22                    0.29                    0.22            -0.2

# %% [markdown]
# We notice that there are states listed here where high schools mandate the **SAT** in order to graduate, yet some of the top average composite scores come from these states. The participation rates for these states are also not within the median range. This could suggest that the low participation rate, combined with high scoring test takers, could skew the mean composite score for that state as compared to those with higher participation rates.

# %% [markdown]
# ### Top 5 states with lowest ACT average composite scores in 2017 and 2018

# %%
data.sort_values('act_2017_composite',ascending=True)[['state','act_2017_composite', 'act_2018_composite','act_2017_participation','act_2018_participation','composite_diff']].head()
# Out:
#              state  act_2017_composite  act_2018_composite  \
# 28          Nevada                17.6                17.7
# 20        Maryland                18.2                22.5
# 24     Mississippi                18.5                18.6
# 40  South Carolina                18.5                18.3
# 11          Hawaii                18.9                18.9
#
#     act_2017_participation  act_2018_participation  composite_diff
# 28                    1.00                    1.00            -0.1
# 20                    0.28                    0.31            -4.3
# 24                    1.00                    1.00            -0.1
# 40                    1.00                    1.00             0.2
# 11                    0.90                    0.89             0.0

# %%
data.sort_values('act_2018_composite',ascending=True)[['state','act_2017_composite', 'act_2018_composite','act_2017_participation','act_2018_participation','composite_diff']].head()
# Out:
#              state  act_2017_composite  act_2018_composite  \
# 28          Nevada                17.6                17.7
# 40  South Carolina                18.5                18.3
# 24     Mississippi                18.5                18.6
# 11          Hawaii                18.9                18.9
# 0          Alabama                19.1                19.1
#
#     act_2017_participation  act_2018_participation  composite_diff
# 28                     1.0                    1.00            -0.1
# 40                     1.0                    1.00             0.2
# 24                     1.0                    1.00            -0.1
# 11                     0.9                    0.89             0.0
# 0                      1.0                    1.00             0.0

# %% [markdown]
# Incidentally, some of the states with the lowest average composite scores have high participation rates. The high participation rates, combined with the bulk of test takers would bring down the average composite scores.

# %% [markdown]
# ### Top 5 states with highest SAT average total scores in 2017 and 2018

# %%
data.sort_values('sat_2017_total',ascending=False)[['state','sat_2017_total', 'sat_2018_total','sat_2017_participation','sat_2018_participation','total_diff']].head()
# Out:
#         state  sat_2017_total  sat_2018_total  sat_2017_participation  \
# 23  Minnesota            1295            1298                    0.03
# 49  Wisconsin            1291            1294                    0.03
# 15       Iowa            1276            1265                    0.02
# 25   Missouri            1271            1262                    0.03
# 16     Kansas            1260            1264                    0.04
#
#     sat_2018_participation  total_diff
# 23                    0.04          -3
# 49                    0.03          -3
# 15                    0.03          11
# 25                    0.04           9
# 16                    0.04          -4

# %%
data.sort_values('sat_2018_total',ascending=False)[['state','sat_2017_total', 'sat_2018_total','sat_2017_participation','sat_2018_participation','total_diff']].head()
# Out:
#            state  sat_2017_total  sat_2018_total  sat_2017_participation  \
# 23     Minnesota            1295            1298                    0.03
# 49     Wisconsin            1291            1294                    0.03
# 34  North Dakota            1256            1283                    0.02
# 15          Iowa            1276            1265                    0.02
# 16        Kansas            1260            1264                    0.04
#
#     sat_2018_participation  total_diff
# 23                    0.04          -3
# 49                    0.03          -3
# 34                    0.02         -27
# 15                    0.03          11
# 16                    0.04          -4

# %% [markdown]
# We see the same biased high average SAT totals in states with low participation rates

# %% [markdown]
# ### Top 5 states with lowest SAT average total scores in 2017 and 2018

# %%
data.sort_values('sat_2017_total',ascending=True)[['state','sat_2017_total', 'sat_2018_total','sat_2017_participation','sat_2018_participation','total_diff']].head()
# Out:
#                    state  sat_2017_total  sat_2018_total  \
# 8   District of Columbia             950             977
# 7               Delaware             995             997
# 22              Michigan            1004            1010
# 12                 Idaho            1006            1001
# 19                 Maine            1012            1013
#
#     sat_2017_participation  sat_2018_participation  total_diff
# 8                     1.00                    0.92         -27
# 7                     1.00                    1.00          -2
# 22                    1.00                    1.00          -6
# 12                    0.93                    1.00           5
# 19                    0.95                    0.99          -1

# %%
data.sort_values('sat_2018_total',ascending=True)[['state','sat_2017_total', 'sat_2018_total','sat_2017_participation','sat_2018_participation','total_diff']].head()
# Out:
#                    state  sat_2017_total  sat_2018_total  \
# 8   District of Columbia             950             977
# 7               Delaware             995             997
# 48         West Virginia            1086             999
# 12                 Idaho            1006            1001
# 44                  Utah            1238            1010
#
#     sat_2017_participation  sat_2018_participation  total_diff
# 8                     1.00                    0.92         -27
# 7                     1.00                    1.00          -2
# 48                    0.14                    0.28          87
# 12                    0.93                    1.00           5
# 44                    0.03                    0.04         228

# %% [markdown]
# And also the same low average total scores in states with high participation rates. We also notice a huge drop for average SAT scores in Utah. On further research for the SAT test on 25th August 2018, there were reports of SAT questions leaked / reused in the previous year's SAT. Utah also had to deal with wildfires earlier in July that year.

# %% [markdown]
# ### States with 100% ACT participation by difference between 2017 and 2018

# %%
data.loc[((data['act_2017_participation'] == 1) | (data['act_2018_participation'] == 1))  & (data['act_participation_diff'] != 0),['state','act_2017_participation','act_2018_participation','act_participation_diff']]
# Out:
#         state  act_2017_participation  act_2018_participation  \
# 5    Colorado                    1.00                    0.30
# 23  Minnesota                    1.00                    0.99
# 27   Nebraska                    0.84                    1.00
# 35       Ohio                    0.75                    1.00
#
#     act_participation_diff
# 5                     0.70
# 23                    0.01
# 27                    0.16
# 35                    0.25

# %% [markdown]
# While other states have an increase towards 2018 in ACT participation rate, Colorado's ACT participation has dropped by 70%. This is due the the change from ACT to mandatory SAT testing.

# %% [markdown]
# ### States with 100% SAT Participation by difference between 2017 and 2018

# %%
data.loc[((data['sat_2017_participation'] == 1) | (data['sat_2018_participation'] == 1)) & (data['sat_participation_diff'] != 0),['state','sat_2017_participation','sat_2018_participation','sat_participation_diff']]
# Out:
#                    state  sat_2017_participation  sat_2018_participation  \
# 5               Colorado                    0.11                    1.00
# 8   District of Columbia                    1.00                    0.92
# 12                 Idaho                    0.93                    1.00
#
#     sat_participation_diff
# 5                     0.89
# 8                     0.08
# 12                    0.07

# %% [markdown]
# And evidently, Colorado's participation rate in 2018 shot up by almost 90% after implementing mandatory SAT testing in 2017.

# %%
data.loc[
    ((data['act_2017_participation'] >= 0.5) | (data['act_2018_participation'] >= 0.5)) & 
    ((data['sat_2017_participation'] >= 0.5) | (data['sat_2018_participation'] >= 0.5)),['state','act_2017_participation','act_2018_participation','sat_2017_participation','sat_2018_participation','composite_diff','total_diff']]
# Out:
#              state  act_2017_participation  act_2018_participation  \
# 5         Colorado                    1.00                    0.30
# 9          Florida                    0.73                    0.66
# 10         Georgia                    0.55                    0.53
# 11          Hawaii                    0.90                    0.89
# 13        Illinois                    0.93                    0.43
# 33  North Carolina                    1.00                    1.00
# 40  South Carolina                    1.00                    1.00
#
#     sat_2017_participation  sat_2018_participation  composite_diff  total_diff
# 5                     0.11                    1.00            -3.3         176
# 9                     0.83                    0.56            -0.2         -82
# 10                    0.61                    0.70            -0.1         -14
# 11                    0.55                    0.56             0.0          75
# ...

# %%
data.loc[(data['state'].isin(['Colorado','Illinois'])),['state','act_2017_participation','act_2018_participation','sat_2017_participation','sat_2018_participation','act_participation_diff','sat_participation_diff']]
# Out:
#        state  act_2017_participation  act_2018_participation  \
# 5   Colorado                    1.00                    0.30
# 13  Illinois                    0.93                    0.43
#
#     sat_2017_participation  sat_2018_participation  act_participation_diff  \
# 5                     0.11                    1.00                     0.7
# 13                    0.09                    0.99                     0.5
#
#     sat_participation_diff
# 5                     0.89
# 13                    0.90

# %% [markdown]
# Focusing on Colorado and Illinois, we see large swings in Colorado and Illinois in terms of participation rates from 2017 to 2018, due to the switch of ACT to SAT testing. ACT participation rates for both states dropped in 2018.
#
# https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
mask = np.zeros_like(data.corr())
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(15,15))
plt.title('Correlation Heatmap of 2017-2018 ACT & SAT Scores and Participation',{'fontsize':20})
sns.heatmap(np.abs(data.corr()), mask=mask, annot=True);

# %% [markdown]
# We note values that are nearer to 1, as they show a correlation / inverse correlation. As such, we can see the individual scores from the ACT (English, Math, Reading and Science) strongly correlated to the composite score, and similarly for the SAT (EBRW and Math) to the Total, which is logically correct since individual test scores will correlate to the total/composite.
#
# We also see that the ACT participation % are correlated to SAT participation %.

# %%
data.describe().T
# Out:
#                         count         mean        std     min       25%  \
# act_2017_participation   51.0     0.652549   0.321408    0.08     0.310
# act_2017_english         51.0    20.931373   2.353677   16.30    19.000
# act_2017_math            51.0    21.182353   1.981989   18.00    19.400
# act_2017_reading         51.0    22.013725   2.067271   18.10    20.450
# act_2017_science         51.0    21.041176   3.182463    2.30    19.900
# act_2017_composite       51.0    21.292157   2.050058   17.60    19.700
# act_2018_participation   51.0     0.617255   0.340371    0.07     0.285
# act_2018_composite       51.0    21.496078   2.111583   17.70    19.950
# sat_2017_participation   51.0     0.398039   0.352766    0.02     0.040
# sat_2017_ebrw            51.0   569.117647  45.666901  482.00   533.500
# sat_2017_math            51.0   556.882353  47.121395  468.00   523.500
# sat_2017_total           51.0  1126.000000  92.487621  950.00  1055.500
# ...

# %%
fig, ax = plt.subplots(1,2, sharex=False, figsize=(15,8))
fig.suptitle('ACT and SAT score Comparison by Year', fontsize=15)

sns.histplot([data['act_2017_composite'],data['act_2018_composite']], alpha=0.4, palette=['#0343df',"#dc143c"], kde=True, ax=ax[0])
ax[0].set_title('ACT 2017 vs 2018')
ax[0].set(xlabel='Average Composite')
ax[0].set(ylabel='Count')

sns.histplot([data['sat_2017_total'],data['sat_2018_total']], alpha=0.4, palette=['#0343df',"#dc143c"], kde=True, ax=ax[1])
ax[1].set_title('SAT 2017 vs 2018')
ax[1].set(xlabel='Average Total')
ax[1].set(ylabel='Count');

# %% [markdown]
# We can see there minor differences between the distributions of composite scores between 2017 and 2018 ACT results. On showing the KDE curve, we see a bimodal distribution, where there are 2 peaks. Students perform either very poorly or very well.

# %%
fig, ax = plt.subplots(1,2, sharex=True, figsize=(15,8))
fig.suptitle('ACT and SAT Pariticipation Comparison by Year', fontsize=15)

sns.histplot([data['act_2017_participation'],data['act_2018_participation']], alpha=0.4, palette=['#0343df',"#dc143c"], kde=True, ax=ax[0])
ax[0].set_title('ACT 2017 vs 2018')
ax[0].set(xlabel='Average Participation %')
ax[0].set(ylabel='Count')

sns.histplot([data['sat_2017_participation'],data['sat_2018_participation']], alpha=0.4, palette=['#0343df',"#dc143c"], kde=True, ax=ax[1])
ax[1].set_title('SAT 2017 vs 2018')
ax[1].set(xlabel='Average Participation %')
ax[1].set(ylabel='Count');

# %% [markdown]
# The participation rates for both ACT and SAT in 2017 and 2018 respectively, are also roughly similar. There is a slight increase in participation rate for the SAT in 2018, seeing that the average participation % from the 0 to 20% range has reduced, and increased in the 80-100% range. This shows an increase in acceptance towards SAT, given that the ACT has been reigning as the top test taken since 2012

# %%
fig, ax = plt.subplots(1,2, sharex=True, figsize=(15,8))
fig.suptitle('Comparison of ACT and SAT Participation by Year', fontsize=15)


sns.histplot([data['act_2017_participation'],data['sat_2017_participation']], alpha=0.4, palette=['#0343df',"#dc143c"], ax=ax[0])
ax[0].set_title('ACT 2017 vs SAT 2017')
ax[0].set(xlabel='Average Participation %')
ax[0].set(ylabel='Count')

sns.histplot([data['act_2018_participation'],data['sat_2018_participation']], alpha=0.4, palette=['#0343df',"#dc143c"], ax=ax[1])
ax[1].set_title('ACT 2018 vs SAT 2018')
ax[1].set(xlabel='Average Participation %')
ax[1].set(ylabel='Count');

# %% [markdown]
# However, when we compare the we notice that the Participation % count between ACT and SAT in 2017 is inverse, showing lesser participation for the SAT against ACT in some states. This trend is noted in 2018 too.

# %%
plt.figure(figsize=(10,10))
participation_rates = data[['act_2017_participation','act_2018_participation','sat_2017_participation','sat_2018_participation']]
participation_rates = participation_rates.rename(columns={
    'act_2017_participation':'ACT 2017',
    'act_2018_participation':'ACT 2018',
    'sat_2017_participation':'SAT 2017',
    'sat_2018_participation':'SAT 2018'
    
})
sns.boxplot(data=participation_rates, palette=['#488f31','#488f31','#de425b','#de425b'])
plt.title('ACT vs SAT Participation Rates', {'fontsize':15})
plt.xlabel('Year of Participation %')
plt.ylabel('Participation Rates');

# %% [markdown]
# In the boxplot above, we can see the ACT is more favoured than the SAT in terms of participation. The mean participation for the ACT is almost or more than the 75th quantile of the participation in 2017's SAT. However, we start to see a shift for the adoption of SATs in 2018, with the average growing significantly vs SATs in 2017. This could be partly due to more acceptance to the redesigned SATs in 2016. Additionally, there are some states that switched over from the ACT to SAT, such as Colorado and Illinois.

# %%
fig, ax = plt.subplots(1,2, sharex=True, figsize=(15,8))
fig.suptitle('Comparison of 2017 and 2018 ACT Participation vs Composite Score', fontsize=15)

sns.scatterplot(x=data['act_2017_participation'], y=data['act_2017_composite'], ax=ax[0])
ax[0].set_title('2017 ACT Participation vs Composite Scores')
ax[0].set(xlabel='Average Participation')
ax[0].set(ylabel='Average Composite Score')

sns.scatterplot(x=data['act_2018_participation'], y=data['act_2018_composite'], ax=ax[1])
ax[1].set_title('2018 ACT Participation vs Composite Scores')
ax[1].set(xlabel='Average Participation')
ax[1].set(ylabel='Average Composite Score');

# %% [markdown]
# We can see a negative correlation where there are higher mean scores in states with lower mean participation. We also see a cluster of the composite scores between the 19-21 range with higher participation. This would mean that there are a higher volume of students (high and low achievers) participating, as compared to states with lesser participation which could have mostly higher scoring students.

# %%
fig, ax = plt.subplots(1,2, sharex=True, figsize=(15,8))
fig.suptitle('Comparison of 2017 and 2018 SAT Participation vs Composite Score', fontsize=15)

sns.scatterplot(x=data['sat_2017_participation'], y=data['sat_2017_total'], ax=ax[0])
ax[0].set_title('2017 SAT Participation vs Total Scores')
ax[0].set(xlabel='Average Participation')
ax[0].set(ylabel='Average Composite Score')

sns.scatterplot(x=data['sat_2018_participation'], y=data['sat_2018_total'], ax=ax[1])
ax[1].set_title('2018 SAT Participation vs Total Scores')
ax[1].set(xlabel='Average Participation')
ax[1].set(ylabel='Average Composite Score');

# %% [markdown]
# Conversely, we see a cluster of higher total scores for the SAT in states with lower participation rates. We can infer that there are higher scoring students in states with lower participation, as it makes it easier for the students to be placed within the higher quartile range.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# From the findings above, we can see that the ACT and SAT average composite and total scores are inversely correlated with their participation rates in the respective states. This is likely due to selection bias, where we see test takers participating in low participation states tend to score better, and states with higher participation have a diluted average of scores due to the higher amount of participants.
#
# Averaging ACT or SAT scores by state helps colleges to set standards for admission, likely towards public universities with automatic admissions for in-state students.<sup>1</sup> https://magoosh.com/hs/sat/average-sat-scores-by-state-how-does-your-state-stack-up/ Thus, it does carry a slight benefit for students looking to enter universities via such automatic admissions from their in-state colleges. There are other factors too, such as tuition fees and discounts for in-state students versus out-of-state students.
#
# Although the ACT has been the reigning test since 2012, we can see a shift towards the SAT after its redesign in 2016, which removed the penalty on deducting scores for getting the wrong answer. However, there are other push factors on seeing the increase in acceptance for SAT in some states. The College Board pushes for statewide testing contracts, which can swing a state's staple test such as the ACT, to the SAT. <sup>2</sup>https://www.edweek.org/teaching-learning/illinois-chooses-sat-over-act-for-statewide-college-readiness-testing/2015/12 <sup>3</sup>https://www.newamerica.org/education-policy/edcentral/how-college-boards-aggressive-campaign-to-save-the-sat-may-kill-it/ The College Board has also partnered with Khan Academy for free SAT preparation. This in turn would promote higher participation rates to the SAT.
#
#
# The SAT tests only have 2 sections, Evidence-Based Reading and Writing (EBRW) and Math, whereas the ACT has 4 sections, English, Math, Reading and Science. Although the SAT has portions in the EBRW which contains elements of Science topics, the test doesn't necessarily target the topic directly as compared to the ACT. Additionally, because the SAT has one paper focused on math, students who are weaker in math might find their overall total score to be affected due to a higher weightage for the total score as compared to the ACT. Test takers would likely choose the ACT as it is more straightforward with its 4 sections of testing targeted at the various topics directly. However, students who are more proficient at math and EBRW would fare better if they took the SAT instead of the ACT.
#
#
# Students in various states might not have the chance to choose whether to take the ACT or SAT, as different states require different tests. The scores for a student in a particular state which requires the SAT, might not be indicative of their true potential if they are weak in math. -- to insert chart here? --
#
# The focus should be shifted to providing better test preparation resources, instead of increasing participation rates. Contracts with the College Board to push higher participation of SAT wouldn't help students if they were not prepared to handle the sections offered, as compared to the ACT.
